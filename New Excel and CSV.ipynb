# %%
# COMBINING 2 EXCEL FILES AND 1 CSV FILE
# df1 = ORDER HISTORICAL

import pandas as pd
orderhistorical=pd.read_excel('Order Historical Data.xlsx')

# %%
orderhistorical.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
orderhistorical.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1927   26104         Medium      0.06        7.10           6.05         3369
# 1928   18311         Medium      0.01      179.29          29.21         3374
# 1929   18320           High      0.05       73.98          12.14         3374
# 1930   18321           High      0.00        5.98           7.15         3374
# 1931   18322           High      0.09        3.57           4.17         3374
#
#      Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1927   Stacy Byrne     Regular Air      Home Office  Office Supplies  ...
# 1928    Jamie Ward  Delivery Truck        Corporate        Furniture  ...
# 1929    Jamie Ward     Regular Air      Home Office       Technology  ...
# 1930    Jamie Ward     Regular Air      Home Office  Office Supplies  ...
# 1931    Jamie Ward     Regular Air      Home Office  Office Supplies  ...
#
# ...

# %%
orderhistorical.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1932.000000  1932.000000  1932.000000    1932.000000  1932.000000
# mean   19890.543996     0.048996   108.903866      13.000399  1718.263975
# std     5978.467577     0.031337   394.505274      17.478981   981.739445
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19111.750000     0.020000     6.480000       3.230000   868.000000
# 50%    21146.500000     0.050000    20.990000       6.150000  1731.500000
# 75%    23483.250000     0.070000   100.970000      14.362500  2555.000000
# max    26389.000000     0.210000  6783.020000     164.730000  3374.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1918.000000   1932.000000   1932.000000           1932.000000
# mean              0.515115  51531.935818    109.550154             12.949275
# ...

# %%
orderhistorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1932 entries, 0 to 1931
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1932 non-null   int64
#  1   Order Priority        1932 non-null   object
#  2   Discount              1932 non-null   float64
#  3   Unit Price            1932 non-null   float64
#  4   Shipping Cost         1932 non-null   float64
#  5   Customer ID           1932 non-null   int64
#  6   Customer Name         1932 non-null   object
#  7   Ship Mode             1932 non-null   object
#  8   Customer Segment      1932 non-null   object
#  9   Product Category      1932 non-null   object
#  10  Product Sub-Category  1932 non-null   object
#  11  Product Container     1932 non-null   object
#  12  Product Name          1932 non-null   object
#  13  Product Base Margin   1918 non-null   float64
#  14  Country               1932 non-null   object
# ...

# %%
print(orderhistorical)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1927   26104         Medium      0.06        7.10           6.05         3369
# 1928   18311         Medium      0.01      179.29          29.21         3374
# 1929   18320           High      0.05       73.98          12.14         3374
# 1930   18321           High      0.00        5.98           7.15         3374
# 1931   18322           High      0.09        3.57           4.17         3374
#
# ...

# %%
# DF2 = ORDER WEEK
orderweek=pd.read_excel('Order Week.xlsx')

# %%
orderweek.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   22378       Critical      0.00       19.98           5.97         3379
# 1   20366       Critical      0.05        3.14           1.92         3379
# 2   23181       Critical      0.03      315.98          19.99         3380
# 3   23182       Critical      0.09      276.20          24.49         3380
# 4   23183       Critical      0.03       63.94          14.48         3380
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Annette McIntyre  Express Air        Corporate  Office Supplies  ...
# 1  Annette McIntyre  Express Air      Home Office  Office Supplies  ...
# 2        Eva Decker  Regular Air      Home Office  Office Supplies  ...
# 3        Eva Decker  Regular Air      Home Office        Furniture  ...
# 4        Eva Decker  Regular Air      Home Office        Furniture  ...
#
#   Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
orderweek.tail()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 15   19842           High      0.01       10.90           7.46         3397
# 16   19843           High      0.10        7.99           5.03         3397
# 17   26208  Not Specified      0.08       11.97           5.81         3399
# 18   24911         Medium      0.10        9.38           4.93         3400
# 19   25914           High      0.10      105.98          13.99         3403
#
#     Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 15    Andrea Shaw  Regular Air   Small Business  Office Supplies  ...
# 16    Andrea Shaw  Regular Air   Small Business       Technology  ...
# 17    Marvin Reid  Regular Air   Small Business  Office Supplies  ...
# 18  Florence Gold  Express Air   Small Business        Furniture  ...
# 19  Tammy Buckley  Express Air         Consumer        Furniture  ...
#
#      Region State or Province         City  Postal Code Order Date  Ship Date  \
# ...

# %%
orderweek.describe()
# Out:
#              Row ID   Discount   Unit Price  Shipping Cost  Customer ID  \
# count     20.000000  20.000000    20.000000      20.000000    20.000000
# mean   22421.850000   0.047000   126.018500       9.853000  3388.450000
# std     2316.460373   0.035997   284.019401       8.983707     8.133589
# min    18640.000000   0.000000     2.610000       0.500000  3379.000000
# 25%    20235.250000   0.017500     9.032500       4.322500  3380.750000
# 50%    22779.500000   0.040000    22.680000       6.715000  3386.000000
# 75%    23433.500000   0.080000   110.982500      14.112500  3397.000000
# max    26208.000000   0.100000  1270.990000      35.000000  3403.000000
#
#        Product Base Margin   Postal Code       Profit  Quantity ordered new  \
# count            18.000000     20.000000    20.000000             20.000000
# mean              0.522778  51808.500000   621.335681             12.500000
# std               0.130420  24772.268692  1565.469339              7.910686
# ...

# %%
orderweek.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                20 non-null     int64
#  1   Order Priority        20 non-null     object
#  2   Discount              20 non-null     float64
#  3   Unit Price            20 non-null     float64
#  4   Shipping Cost         20 non-null     float64
#  5   Customer ID           20 non-null     int64
#  6   Customer Name         20 non-null     object
#  7   Ship Mode             20 non-null     object
#  8   Customer Segment      20 non-null     object
#  9   Product Category      20 non-null     object
#  10  Product Sub-Category  20 non-null     object
#  11  Product Container     20 non-null     object
#  12  Product Name          20 non-null     object
#  13  Product Base Margin   18 non-null     float64
#  14  Country               20 non-null     object
# ...

# %%
print(orderweek)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    22378       Critical      0.00       19.98           5.97         3379
# 1    20366       Critical      0.05        3.14           1.92         3379
# 2    23181       Critical      0.03      315.98          19.99         3380
# 3    23182       Critical      0.09      276.20          24.49         3380
# 4    23183       Critical      0.03       63.94          14.48         3380
# 5    24161  Not Specified      0.05       11.97           5.81         3381
# 6    25841         Medium      0.02       28.53           1.49         3381
# 7    22341            Low      0.04        2.98           2.03         3385
# 8    22342            Low      0.01      125.99           8.99         3385
# 9    23190       Critical      0.00        2.61           0.50         3386
# 10   23191       Critical      0.04       25.38           8.99         3386
# ...

# %%
# DF3 = USER
user=pd.read_csv('User.csv')

# %%
user.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
user.describe()
# Out:
#          Region Manager
# count         4       4
# unique        4       4
# top     Central   Chris
# freq          1       1

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Region   4 non-null      object
#  1   Manager  4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
print(user)
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df1=pd.concat([orderhistorical,orderweek])

# %%
print(df1)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# ..     ...            ...       ...         ...            ...          ...
# 15   19842           High      0.01       10.90           7.46         3397
# 16   19843           High      0.10        7.99           5.03         3397
# 17   26208  Not Specified      0.08       11.97           5.81         3399
# 18   24911         Medium      0.10        9.38           4.93         3400
# 19   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
df1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df1.tail()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 15   19842           High      0.01       10.90           7.46         3397
# 16   19843           High      0.10        7.99           5.03         3397
# 17   26208  Not Specified      0.08       11.97           5.81         3399
# 18   24911         Medium      0.10        9.38           4.93         3400
# 19   25914           High      0.10      105.98          13.99         3403
#
#     Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 15    Andrea Shaw  Regular Air   Small Business  Office Supplies  ...
# 16    Andrea Shaw  Regular Air   Small Business       Technology  ...
# 17    Marvin Reid  Regular Air   Small Business  Office Supplies  ...
# 18  Florence Gold  Express Air   Small Business        Furniture  ...
# 19  Tammy Buckley  Express Air         Consumer        Furniture  ...
#
#      Region State or Province         City  Postal Code Order Date  Ship Date  \
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# ..     ...            ...       ...         ...            ...          ...
# 15   19842           High      0.01       10.90           7.46         3397
# 16   19843           High      0.10        7.99           5.03         3397
# 17   26208  Not Specified      0.08       11.97           5.81         3399
# 18   24911         Medium      0.10        9.38           4.93         3400
# 19   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
df1.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1936.000000   1952.000000   1952.000000           1952.000000
# mean              0.515186  51534.769467    114.793859             12.944672
# ...

# %%
result=pd.merge(df1,user,on='Region')

# %%
print(result)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      23890           High      0.05       26.48           6.93           18
# 3      24063  Not Specified      0.07       12.99           9.44           19
# 4      20631           High      0.06       55.48          14.30           24
# ...      ...            ...       ...         ...            ...          ...
# 1947   23181       Critical      0.03      315.98          19.99         3380
# 1948   23182       Critical      0.09      276.20          24.49         3380
# 1949   23183       Critical      0.03       63.94          14.48         3380
# 1950   24161  Not Specified      0.05       11.97           5.81         3381
# 1951   25841         Medium      0.02       28.53           1.49         3381
#
# ...

# %%
result.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   23890           High      0.05       26.48           6.93           18
# 3   24063  Not Specified      0.07       12.99           9.44           19
# 4   20631           High      0.06       55.48          14.30           24
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0   Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2    Laurie Hanna     Regular Air   Small Business        Furniture  ...
# 3     Jim Rodgers     Regular Air   Small Business       Technology  ...
# 4     Edna Thomas     Regular Air        Corporate  Office Supplies  ...
#
#   State or Province           City Postal Code  Order Date  Ship Date  \
# ...

# %%
result.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1947   23181       Critical      0.03      315.98          19.99         3380
# 1948   23182       Critical      0.09      276.20          24.49         3380
# 1949   23183       Critical      0.03       63.94          14.48         3380
# 1950   24161  Not Specified      0.05       11.97           5.81         3381
# 1951   25841         Medium      0.02       28.53           1.49         3381
#
#                      Customer Name    Ship Mode Customer Segment  \
# 1947                    Eva Decker  Regular Air      Home Office
# 1948                    Eva Decker  Regular Air      Home Office
# 1949                    Eva Decker  Regular Air      Home Office
# 1950  Christopher Norton Patterson  Regular Air        Corporate
# 1951  Christopher Norton Patterson  Regular Air      Home Office
#
#      Product Category  ... State or Province       City Postal Code  \
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1952 entries, 0 to 1951
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
result.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1936.000000   1952.000000   1952.000000           1952.000000
# mean              0.515186  51534.769467    114.793859             12.944672
# ...

# %%
result.to_excel(r'C:\Users\91911\Downloads\ATI Practice\R for superstore\Output\Result.xlsx',sheet_name='Results',index= True)
